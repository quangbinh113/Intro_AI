# %% [markdown]
# # **I. Import library and load data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from xgboost import XGBRegressor
import lightgbm as lgb

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/machine learning project/processed data.csv")
data = data.drop(columns = ['Unnamed: 0'])
data.head()
# Out:
#    MP   Min  Goals  Assists  CrdY  CrdR        Comp  Shots  Acceleration  \
# 0  34  2983   0.06     0.00  0.15  0.03     Ligue 1   0.54            37
# 1  31  2462   0.04     0.00  0.44  0.11     Ligue 1   0.66            50
# 2  34  2956   0.00     0.06  0.27  0.00     Ligue 1   0.91            77
# 3  24   726   0.00     0.12  0.37  0.00  Bundesliga   2.22            81
# 4  30  2536   0.14     0.00  0.07  0.04     Serie A   0.57            64
#
#    Aggression  ...  Vision  Volleys  age               name  overall  \
# 0          81  ...      45       24   33   Yunis Abdelhamid       76
# 1          79  ...      65       38   21  Salis Abdul Samed       70
# 2          76  ...      66       37   28    Laurent Abergel       75
# 3          39  ...      44       53   22     Dickson Abiama       68
# 4          77  ...      65       39   33   Francesco Acerbi       83
#
#    potential  preferred_foot  position common  market value  wage value
# 0         76            Left         defender     3600000.0     23000.0
# 1         75           Right       midfielder     2200000.0      7000.0
# 2         75           Right       midfielder     4900000.0     18000.0
# 3         76           Right          striker     2700000.0      9000.0
# 4         83            Left         defender    17500000.0     75000.0
#
# [5 rows x 52 columns]

# %% [markdown]
# # **II. Convert category data into numeric data and remove columns that don't related in build model**

# %%
# Comp = name of league
data['Comp'].replace(data['Comp'].unique(),[1, 3, 2, 4, 5], inplace=True)
# drop name column and preferred_foot
data = data.drop(columns = ['name','preferred_foot'])

# %%
#convert the categorical variables to dummies
data = pd.get_dummies(data) 
# log tranformation for market vakue
data['market value'] = np.log(data['market value'])
data.head()
# Out:
#    MP   Min  Goals  Assists  CrdY  CrdR  Comp  Shots  Acceleration  \
# 0  34  2983   0.06     0.00  0.15  0.03     1   0.54            37
# 1  31  2462   0.04     0.00  0.44  0.11     1   0.66            50
# 2  34  2956   0.00     0.06  0.27  0.00     1   0.91            77
# 3  24   726   0.00     0.12  0.37  0.00     3   2.22            81
# 4  30  2536   0.14     0.00  0.07  0.04     2   0.57            64
#
#    Aggression  ...  Volleys  age  overall  potential  market value  \
# 0          81  ...       24   33       76         76     15.096444
# 1          79  ...       38   21       70         75     14.603968
# 2          76  ...       37   28       75         75     15.404746
# 3          39  ...       53   22       68         76     14.808762
# 4          77  ...       39   33       83         83     16.677711
#
#    wage value  position common_defender  position common_goalkeeper  \
# 0     23000.0                         1                           0
# 1      7000.0                         0                           0
# 2     18000.0                         0                           0
# 3      9000.0                         0                           0
# 4     75000.0                         1                           0
#
#    position common_midfielder  position common_striker
# 0                           0                        0
# 1                           1                        0
# 2                           1                        0
# 3                           0                        1
# 4                           0                        0
#
# [5 rows x 53 columns]

# %% [markdown]
# # **III. Standardization, split training and test**

# %%
data_build = data.copy()
y = data_build['market value']
x = data_build.drop(columns =['market value'])
# Standardization
def standard_scale(x):
    convert = StandardScaler().fit(x)
    return convert.transform(x)
column = x.columns
x = standard_scale(x)
x_train, x_test, y_train, y_test = train_test_split(x,y , test_size = 0.33, random_state = 3 )

x_train = pd.DataFrame(x_train, columns = column)
x_test =  pd.DataFrame(x_test, columns = column)

# %% [markdown]
# # **IV.Emsemble models : Stacking**

# %% [markdown]
# # 1. Layer1 : Lasso, Ridge, Tree, Forest

# %%
def Stacking(model, train, y, test ):
    folds = KFold(n_splits = 5)
    test_pred = []
    train_pred= []
    for train_index, val_index in folds.split(train, y):
        
        x_train = train.iloc[train_index]
        x_val = train.iloc[val_index]
        y_train = y.iloc[train_index]
        y_val= y.iloc[val_index]
        
        model.fit(x_train, y_train)
        for i in model.predict(x_val):
            train_pred.append(i)
        test_pred.append(list(model.predict(test)))
    test_pred = np.average(np.array(test_pred), axis=0)
    return test_pred, train_pred


model1 = Lasso(alpha = 0.005)
test_pred_1 ,train_pred_1 = Stacking(model1, x_train, y_train, x_test) 
train_pred_1 = pd.DataFrame(train_pred_1)
test_pred_1 = pd.DataFrame(test_pred_1)

model2 = Ridge(alpha = 0.4)
test_pred_2 ,train_pred_2 = Stacking(model2, x_train, y_train, x_test) 
train_pred_2 = pd.DataFrame(train_pred_2)
test_pred_2 = pd.DataFrame(test_pred_2)



model3 = DecisionTreeRegressor(random_state = 3,criterion = 'friedman_mse', max_depth = 16 ,max_features = None,
                              min_samples_leaf = 2 )
test_pred_3 ,train_pred_3 = Stacking(model3, x_train, y_train, x_test) 
train_pred_3 = pd.DataFrame(train_pred_3)
test_pred_3 = pd.DataFrame(test_pred_3)

model4 = RandomForestRegressor(random_state = 3, n_estimators = 500,
                              max_features = None, min_samples_leaf = 1)
test_pred_4 ,train_pred_4 = Stacking(model4, x_train, y_train, x_test) 
train_pred_4 = pd.DataFrame(train_pred_4)
test_pred_4 = pd.DataFrame(test_pred_4)

# %%
# add predictions of 4 models as  new features
x_train['Lasso'] = train_pred_1.values
x_train['Ridge'] = train_pred_2.values
x_train['Tree'] = train_pred_3.values
x_train['Forest'] = train_pred_4.values


x_test['Lasso'] = test_pred_1.values
x_test['Ridge'] = test_pred_2.values
x_test['Tree'] = test_pred_3.values
x_test['Forest'] = test_pred_4.values

print(x_train.shape)
print(x_test.shape)
# Out:
# (1341, 56)
# (661, 56)

# %% [markdown]
# # 2. Layer 2: XGBoost

# %%
# hyperparameter tuning
regressor = XGBRegressor()

params = {
    'n_estimators': [2000,6000],
    'learning_rate': [x/100 for x in range(1, 21, 2)],
    'max_depth':[int(x) for x in range(3, 11, 2)]
}
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring= scoring_fnc, cv= 5 , verbose= 5)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [06:20:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.009 total time=   4.0s
# [06:20:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.013 total time=   3.9s
# [06:20:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.014 total time=   3.9s
# [06:20:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.013 total time=   3.9s
# [06:20:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.011 total time=   4.0s
# [06:20:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.009 total time=  12.4s
# [06:21:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.013 total time=  12.1s
# [06:21:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.014 total time=  12.1s
# [06:21:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.012 total time=  12.0s
# [06:21:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.011 total time=  12.5s
# [06:21:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.010 total time=   6.6s
# [06:21:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.013 total time=   8.2s
# [06:22:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.016 total time=   6.6s
# [06:22:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.012 total time=   6.6s
# [06:22:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.011 total time=   6.6s
# [06:22:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.010 total time=  19.8s
# [06:22:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.013 total time=  19.4s
# [06:23:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.016 total time=  19.2s
# [06:23:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.012 total time=  21.6s
# [06:23:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.011 total time=  19.9s
# [06:24:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.010 total time=   9.7s
# [06:24:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.013 total time=   9.7s
# [06:24:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.015 total time=   9.6s
# [06:24:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.012 total time=   9.8s
# [06:24:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.011 total time=   9.8s
# [06:24:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.010 total time=  17.0s
# [06:25:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.013 total time=  18.4s
# [06:25:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.015 total time=  16.9s
# [06:25:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.012 total time=  16.5s
# [06:26:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.011 total time=  17.0s
# [06:26:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=2000;, score=-0.011 total time=  12.8s
# [06:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=2000;, score=-0.014 total time=  12.7s
# [06:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=2000;, score=-0.015 total time=  12.4s
# [06:26:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=2000;, score=-0.012 total time=  14.0s
# [06:27:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=2000;, score=-0.011 total time=  12.6s
# [06:27:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=6000;, score=-0.011 total time=  16.0s
# [06:27:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=6000;, score=-0.014 total time=  15.9s
# [06:27:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=6000;, score=-0.015 total time=  15.6s
# [06:28:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=6000;, score=-0.012 total time=  15.6s
# [06:28:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=6000;, score=-0.011 total time=  15.6s
# [06:28:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.03, max_depth=3, n_estimators=2000;, score=-0.009 total time=   4.0s
# [06:28:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.03, max_depth=3, n_estimators=2000;, score=-0.013 total time=   4.9s
# [06:28:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.03, max_depth=3, n_estimators=2000;, score=-0.014 total time=   4.7s
# [06:28:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.03, max_depth=3, n_estimators=2000;, score=-0.012 total time=   4.1s
# [06:28:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.03, max_depth=3, n_estimators=2000;, score=-0.011 total time=   4.0s
# [06:29:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.03, max_depth=3, n_estimators=6000;, score=-0.008 total time=  12.3s
# [06:29:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.03, max_depth=3, n_estimators=6000;, score=-0.013 total time=  12.2s
# [06:29:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.03, max_depth=3, n_estimators=6000;, score=-0.014 total time=  12.3s
# [06:29:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.03, max_depth=3, n_estimators=6000;, score=-0.012 total time=  12.2s
# [06:29:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.03, max_depth=3, n_estimators=6000;, score=-0.011 total time=  12.3s
# [06:30:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.03, max_depth=5, n_estimators=2000;, score=-0.009 total time=   6.6s
# [06:30:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.03, max_depth=5, n_estimators=2000;, score=-0.012 total time=   6.5s
# [06:30:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.03, max_depth=5, n_estimators=2000;, score=-0.015 total time=   6.4s
# [06:30:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.03, max_depth=5, n_estimators=2000;, score=-0.012 total time=   6.6s
# [06:30:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.03, max_depth=5, n_estimators=2000;, score=-0.011 total time=   8.0s
# [06:30:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.03, max_depth=5, n_estimators=6000;, score=-0.009 total time=   9.7s
# [06:30:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.03, max_depth=5, n_estimators=6000;, score=-0.012 total time=   9.6s
# [06:30:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.03, max_depth=5, n_estimators=6000;, score=-0.015 total time=   9.6s
# [06:31:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.03, max_depth=5, n_estimators=6000;, score=-0.012 total time=   9.8s
# [06:31:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.03, max_depth=5, n_estimators=6000;, score=-0.011 total time=   9.8s
# [06:31:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.03, max_depth=7, n_estimators=2000;, score=-0.011 total time=   5.7s
# [06:31:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.03, max_depth=7, n_estimators=2000;, score=-0.013 total time=   5.5s
# [06:31:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.03, max_depth=7, n_estimators=2000;, score=-0.015 total time=   5.5s
# [06:31:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.03, max_depth=7, n_estimators=2000;, score=-0.012 total time=   5.6s
# [06:31:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.03, max_depth=7, n_estimators=2000;, score=-0.011 total time=   5.6s
# [06:31:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.03, max_depth=7, n_estimators=6000;, score=-0.011 total time=   8.8s
# [06:32:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.03, max_depth=7, n_estimators=6000;, score=-0.013 total time=   8.8s
# [06:32:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.03, max_depth=7, n_estimators=6000;, score=-0.015 total time=   8.8s
# [06:32:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.03, max_depth=7, n_estimators=6000;, score=-0.012 total time=  10.4s
# [06:32:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.03, max_depth=7, n_estimators=6000;, score=-0.011 total time=   8.9s
# [06:32:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.03, max_depth=9, n_estimators=2000;, score=-0.011 total time=   5.4s
# [06:32:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.03, max_depth=9, n_estimators=2000;, score=-0.013 total time=   5.2s
# [06:32:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.03, max_depth=9, n_estimators=2000;, score=-0.015 total time=   5.2s
# [06:32:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.03, max_depth=9, n_estimators=2000;, score=-0.012 total time=   5.3s
# [06:33:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.03, max_depth=9, n_estimators=2000;, score=-0.011 total time=   5.3s
# [06:33:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.03, max_depth=9, n_estimators=6000;, score=-0.011 total time=   8.6s
# [06:33:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.03, max_depth=9, n_estimators=6000;, score=-0.013 total time=   8.4s
# [06:33:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.03, max_depth=9, n_estimators=6000;, score=-0.015 total time=   8.4s
# [06:33:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.03, max_depth=9, n_estimators=6000;, score=-0.012 total time=   8.5s
# [06:33:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.03, max_depth=9, n_estimators=6000;, score=-0.011 total time=   8.4s
# [06:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=-0.009 total time=   4.1s
# [06:33:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=-0.013 total time=   4.1s
# [06:33:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=-0.014 total time=   4.1s
# [06:34:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=-0.012 total time=   4.1s
# [06:34:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=-0.011 total time=   4.1s
# [06:34:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=6000;, score=-0.009 total time=  10.8s
# [06:34:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=6000;, score=-0.013 total time=   9.5s
# [06:34:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=6000;, score=-0.014 total time=   9.3s
# [06:34:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=6000;, score=-0.012 total time=   9.4s
# [06:34:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=6000;, score=-0.011 total time=   9.4s
# [06:34:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=-0.010 total time=   4.6s
# [06:35:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=-0.013 total time=   4.6s
# [06:35:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=-0.016 total time=   4.5s
# [06:35:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=-0.012 total time=   4.6s
# [06:35:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=-0.011 total time=   4.6s
# [06:35:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=6000;, score=-0.010 total time=   7.7s
# [06:35:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=6000;, score=-0.013 total time=   7.8s
# [06:35:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=6000;, score=-0.016 total time=   7.6s
# [06:35:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=6000;, score=-0.012 total time=   7.7s
# [06:35:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=6000;, score=-0.011 total time=   7.8s
# [06:36:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.05, max_depth=7, n_estimators=2000;, score=-0.011 total time=   5.4s
# [06:36:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.05, max_depth=7, n_estimators=2000;, score=-0.014 total time=   4.1s
# [06:36:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.05, max_depth=7, n_estimators=2000;, score=-0.016 total time=   4.1s
# [06:36:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.05, max_depth=7, n_estimators=2000;, score=-0.012 total time=   4.0s
# [06:36:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.05, max_depth=7, n_estimators=2000;, score=-0.012 total time=   4.0s
# [06:36:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.05, max_depth=7, n_estimators=6000;, score=-0.011 total time=   7.2s
# [06:36:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.05, max_depth=7, n_estimators=6000;, score=-0.014 total time=   7.2s
# [06:36:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.05, max_depth=7, n_estimators=6000;, score=-0.016 total time=  12.1s
# [06:36:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.05, max_depth=7, n_estimators=6000;, score=-0.012 total time=  13.2s
# [06:37:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.05, max_depth=7, n_estimators=6000;, score=-0.012 total time=   7.2s
# [06:37:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.05, max_depth=9, n_estimators=2000;, score=-0.012 total time=   3.8s
# [06:37:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.05, max_depth=9, n_estimators=2000;, score=-0.013 total time=   3.8s
# [06:37:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.05, max_depth=9, n_estimators=2000;, score=-0.016 total time=   3.8s
# [06:37:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.05, max_depth=9, n_estimators=2000;, score=-0.012 total time=   3.8s
# [06:37:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.05, max_depth=9, n_estimators=2000;, score=-0.012 total time=   3.8s
# [06:37:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.05, max_depth=9, n_estimators=6000;, score=-0.012 total time=   7.0s
# [06:37:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.05, max_depth=9, n_estimators=6000;, score=-0.013 total time=   7.0s
# [06:37:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.05, max_depth=9, n_estimators=6000;, score=-0.016 total time=   7.0s
# [06:37:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.05, max_depth=9, n_estimators=6000;, score=-0.012 total time=   8.6s
# [06:37:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.05, max_depth=9, n_estimators=6000;, score=-0.012 total time=   7.0s
# [06:38:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.07, max_depth=3, n_estimators=2000;, score=-0.009 total time=   4.1s
# [06:38:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.07, max_depth=3, n_estimators=2000;, score=-0.013 total time=   4.1s
# [06:38:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.07, max_depth=3, n_estimators=2000;, score=-0.015 total time=   4.1s
# [06:38:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.07, max_depth=3, n_estimators=2000;, score=-0.013 total time=   4.1s
# [06:38:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.07, max_depth=3, n_estimators=2000;, score=-0.011 total time=   4.1s
# [06:38:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.07, max_depth=3, n_estimators=6000;, score=-0.009 total time=   8.0s
# [06:38:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.07, max_depth=3, n_estimators=6000;, score=-0.013 total time=   8.5s
# [06:38:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.07, max_depth=3, n_estimators=6000;, score=-0.015 total time=   8.0s
# [06:38:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.07, max_depth=3, n_estimators=6000;, score=-0.013 total time=   8.1s
# [06:38:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.07, max_depth=3, n_estimators=6000;, score=-0.011 total time=   8.2s
# [06:39:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.07, max_depth=5, n_estimators=2000;, score=-0.009 total time=   3.7s
# [06:39:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.07, max_depth=5, n_estimators=2000;, score=-0.013 total time=   3.7s
# [06:39:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.07, max_depth=5, n_estimators=2000;, score=-0.016 total time=   3.7s
# [06:39:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.07, max_depth=5, n_estimators=2000;, score=-0.012 total time=   3.8s
# [06:39:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.07, max_depth=5, n_estimators=2000;, score=-0.011 total time=   3.7s
# [06:39:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.07, max_depth=5, n_estimators=6000;, score=-0.009 total time=   6.8s
# [06:39:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.07, max_depth=5, n_estimators=6000;, score=-0.013 total time=   6.8s
# [06:39:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.07, max_depth=5, n_estimators=6000;, score=-0.016 total time=   8.2s
# [06:39:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.07, max_depth=5, n_estimators=6000;, score=-0.012 total time=   7.2s
# [06:39:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.07, max_depth=5, n_estimators=6000;, score=-0.011 total time=   6.9s
# [06:40:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.07, max_depth=7, n_estimators=2000;, score=-0.010 total time=   3.3s
# [06:40:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.07, max_depth=7, n_estimators=2000;, score=-0.013 total time=   3.3s
# [06:40:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.07, max_depth=7, n_estimators=2000;, score=-0.016 total time=   3.4s
# [06:40:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.07, max_depth=7, n_estimators=2000;, score=-0.012 total time=   3.4s
# [06:40:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.07, max_depth=7, n_estimators=2000;, score=-0.011 total time=   3.3s
# [06:40:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.07, max_depth=7, n_estimators=6000;, score=-0.010 total time=   6.9s
# [06:40:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.07, max_depth=7, n_estimators=6000;, score=-0.013 total time=   6.4s
# [06:40:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.07, max_depth=7, n_estimators=6000;, score=-0.016 total time=   6.5s
# [06:40:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.07, max_depth=7, n_estimators=6000;, score=-0.012 total time=   6.5s
# [06:40:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.07, max_depth=7, n_estimators=6000;, score=-0.011 total time=   6.5s
# [06:40:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.07, max_depth=9, n_estimators=2000;, score=-0.011 total time=   3.2s
# [06:40:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.07, max_depth=9, n_estimators=2000;, score=-0.014 total time=   3.2s
# [06:40:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.07, max_depth=9, n_estimators=2000;, score=-0.016 total time=   3.1s
# [06:40:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.07, max_depth=9, n_estimators=2000;, score=-0.012 total time=   3.2s
# [06:41:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.07, max_depth=9, n_estimators=2000;, score=-0.012 total time=   3.2s
# [06:41:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.07, max_depth=9, n_estimators=6000;, score=-0.011 total time=   6.4s
# [06:41:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.07, max_depth=9, n_estimators=6000;, score=-0.014 total time=   6.5s
# [06:41:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.07, max_depth=9, n_estimators=6000;, score=-0.016 total time=   6.3s
# [06:41:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.07, max_depth=9, n_estimators=6000;, score=-0.012 total time=   6.3s
# [06:41:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.07, max_depth=9, n_estimators=6000;, score=-0.012 total time=   8.0s
# [06:41:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.09, max_depth=3, n_estimators=2000;, score=-0.009 total time=   4.1s
# [06:41:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.09, max_depth=3, n_estimators=2000;, score=-0.013 total time=   4.1s
# [06:41:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.09, max_depth=3, n_estimators=2000;, score=-0.015 total time=   4.1s
# [06:41:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.09, max_depth=3, n_estimators=2000;, score=-0.014 total time=   4.1s
# [06:41:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.09, max_depth=3, n_estimators=2000;, score=-0.012 total time=   4.1s
# [06:41:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.09, max_depth=3, n_estimators=6000;, score=-0.009 total time=   7.3s
# [06:42:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.09, max_depth=3, n_estimators=6000;, score=-0.013 total time=   7.7s
# [06:42:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.09, max_depth=3, n_estimators=6000;, score=-0.015 total time=   7.3s
# [06:42:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.09, max_depth=3, n_estimators=6000;, score=-0.014 total time=   7.4s
# [06:42:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.09, max_depth=3, n_estimators=6000;, score=-0.012 total time=   7.4s
# [06:42:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.09, max_depth=5, n_estimators=2000;, score=-0.010 total time=   3.2s
# [06:42:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.09, max_depth=5, n_estimators=2000;, score=-0.012 total time=   3.3s
# [06:42:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.09, max_depth=5, n_estimators=2000;, score=-0.017 total time=   3.2s
# [06:42:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.09, max_depth=5, n_estimators=2000;, score=-0.013 total time=   3.3s
# [06:42:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.09, max_depth=5, n_estimators=2000;, score=-0.012 total time=   3.2s
# [06:42:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.09, max_depth=5, n_estimators=6000;, score=-0.010 total time=   6.6s
# [06:42:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.09, max_depth=5, n_estimators=6000;, score=-0.012 total time=   6.4s
# [06:43:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.09, max_depth=5, n_estimators=6000;, score=-0.017 total time=   6.5s
# [06:43:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.09, max_depth=5, n_estimators=6000;, score=-0.013 total time=   6.5s
# [06:43:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.09, max_depth=5, n_estimators=6000;, score=-0.012 total time=   6.4s
# [06:43:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.09, max_depth=7, n_estimators=2000;, score=-0.011 total time=   3.1s
# [06:43:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.09, max_depth=7, n_estimators=2000;, score=-0.014 total time=   4.4s
# [06:43:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.09, max_depth=7, n_estimators=2000;, score=-0.016 total time=   2.9s
# [06:43:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.09, max_depth=7, n_estimators=2000;, score=-0.013 total time=   3.0s
# [06:43:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.09, max_depth=7, n_estimators=2000;, score=-0.013 total time=   3.0s
# [06:43:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.09, max_depth=7, n_estimators=6000;, score=-0.011 total time=   6.1s
# [06:43:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.09, max_depth=7, n_estimators=6000;, score=-0.014 total time=   6.2s
# [06:43:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.09, max_depth=7, n_estimators=6000;, score=-0.016 total time=   6.1s
# [06:44:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.09, max_depth=7, n_estimators=6000;, score=-0.013 total time=   6.3s
# [06:44:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.09, max_depth=7, n_estimators=6000;, score=-0.013 total time=   6.2s
# [06:44:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.09, max_depth=9, n_estimators=2000;, score=-0.012 total time=   2.9s
# [06:44:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.09, max_depth=9, n_estimators=2000;, score=-0.013 total time=   2.9s
# [06:44:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.09, max_depth=9, n_estimators=2000;, score=-0.017 total time=   2.8s
# [06:44:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.09, max_depth=9, n_estimators=2000;, score=-0.012 total time=   2.9s
# [06:44:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.09, max_depth=9, n_estimators=2000;, score=-0.012 total time=   2.8s
# [06:44:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.09, max_depth=9, n_estimators=6000;, score=-0.012 total time=   6.0s
# [06:44:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.09, max_depth=9, n_estimators=6000;, score=-0.013 total time=   6.0s
# [06:44:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.09, max_depth=9, n_estimators=6000;, score=-0.017 total time=   6.0s
# [06:44:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.09, max_depth=9, n_estimators=6000;, score=-0.012 total time=   6.0s
# [06:44:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.09, max_depth=9, n_estimators=6000;, score=-0.012 total time=   6.1s
# [06:44:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.11, max_depth=3, n_estimators=2000;, score=-0.009 total time=   3.7s
# [06:45:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.11, max_depth=3, n_estimators=2000;, score=-0.013 total time=   3.7s
# [06:45:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.11, max_depth=3, n_estimators=2000;, score=-0.016 total time=   3.7s
# [06:45:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.11, max_depth=3, n_estimators=2000;, score=-0.013 total time=   3.8s
# [06:45:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.11, max_depth=3, n_estimators=2000;, score=-0.012 total time=   3.7s
# [06:45:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.11, max_depth=3, n_estimators=6000;, score=-0.009 total time=   7.1s
# [06:45:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.11, max_depth=3, n_estimators=6000;, score=-0.013 total time=   8.4s
# [06:45:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.11, max_depth=3, n_estimators=6000;, score=-0.016 total time=   6.8s
# [06:45:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.11, max_depth=3, n_estimators=6000;, score=-0.013 total time=   6.9s
# [06:45:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.11, max_depth=3, n_estimators=6000;, score=-0.012 total time=   6.9s
# [06:45:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.11, max_depth=5, n_estimators=2000;, score=-0.011 total time=   3.0s
# [06:45:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.11, max_depth=5, n_estimators=2000;, score=-0.013 total time=   3.0s
# [06:45:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.11, max_depth=5, n_estimators=2000;, score=-0.017 total time=   3.0s
# ...
# [CV 2/5] END learning_rate=0.17, max_depth=5, n_estimators=2000;, score=-0.014 total time=   2.5s
# [06:54:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.17, max_depth=5, n_estimators=2000;, score=-0.019 total time=   2.5s
# [06:54:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.17, max_depth=5, n_estimators=2000;, score=-0.016 total time=   2.5s
# [06:54:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.17, max_depth=5, n_estimators=2000;, score=-0.012 total time=   2.5s
# [06:54:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.17, max_depth=5, n_estimators=6000;, score=-0.011 total time=   5.7s
# [06:54:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.17, max_depth=5, n_estimators=6000;, score=-0.014 total time=   5.8s
# [06:55:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.17, max_depth=5, n_estimators=6000;, score=-0.019 total time=   6.4s
# [06:55:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.17, max_depth=5, n_estimators=6000;, score=-0.016 total time=   6.5s
# [06:55:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.17, max_depth=5, n_estimators=6000;, score=-0.012 total time=   5.7s
# [06:55:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.17, max_depth=7, n_estimators=2000;, score=-0.013 total time=   2.4s
# [06:55:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.17, max_depth=7, n_estimators=2000;, score=-0.015 total time=   2.3s
# [06:55:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.17, max_depth=7, n_estimators=2000;, score=-0.018 total time=   2.3s
# [06:55:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.17, max_depth=7, n_estimators=2000;, score=-0.016 total time=   2.4s
# [06:55:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.17, max_depth=7, n_estimators=2000;, score=-0.012 total time=   2.3s
# [06:55:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.17, max_depth=7, n_estimators=6000;, score=-0.013 total time=   5.6s
# [06:55:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.17, max_depth=7, n_estimators=6000;, score=-0.015 total time=   5.5s
# [06:55:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.17, max_depth=7, n_estimators=6000;, score=-0.018 total time=   5.5s
# [06:55:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.17, max_depth=7, n_estimators=6000;, score=-0.016 total time=   5.5s
# [06:55:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.17, max_depth=7, n_estimators=6000;, score=-0.012 total time=   5.5s
# [06:56:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.17, max_depth=9, n_estimators=2000;, score=-0.014 total time=   2.3s
# [06:56:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.17, max_depth=9, n_estimators=2000;, score=-0.016 total time=   2.3s
# [06:56:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.17, max_depth=9, n_estimators=2000;, score=-0.018 total time=   2.3s
# [06:56:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.17, max_depth=9, n_estimators=2000;, score=-0.018 total time=   2.3s
# [06:56:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.17, max_depth=9, n_estimators=2000;, score=-0.013 total time=   2.3s
# [06:56:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.17, max_depth=9, n_estimators=6000;, score=-0.014 total time=   5.5s
# [06:56:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.17, max_depth=9, n_estimators=6000;, score=-0.016 total time=   5.5s
# [06:56:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.17, max_depth=9, n_estimators=6000;, score=-0.018 total time=   5.5s
# [06:56:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.17, max_depth=9, n_estimators=6000;, score=-0.018 total time=   5.5s
# [06:56:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.17, max_depth=9, n_estimators=6000;, score=-0.013 total time=   5.4s
# [06:56:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000;, score=-0.010 total time=   2.9s
# [06:56:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000;, score=-0.014 total time=   2.9s
# [06:56:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000;, score=-0.017 total time=   2.9s
# [06:56:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000;, score=-0.017 total time=   2.9s
# [06:56:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000;, score=-0.012 total time=   2.9s
# [06:56:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=6000;, score=-0.010 total time=   6.1s
# [06:57:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=6000;, score=-0.014 total time=   6.0s
# [06:57:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=6000;, score=-0.017 total time=   7.6s
# [06:57:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=6000;, score=-0.017 total time=   6.1s
# [06:57:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=6000;, score=-0.012 total time=   6.0s
# [06:57:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.011 total time=   2.4s
# [06:57:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.014 total time=   2.4s
# [06:57:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.019 total time=   2.4s
# [06:57:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.014 total time=   2.4s
# [06:57:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.013 total time=   2.4s
# [06:57:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.011 total time=   5.6s
# [06:57:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.014 total time=   5.5s
# [06:57:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.019 total time=   5.6s
# [06:57:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.014 total time=   5.6s
# [06:58:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.013 total time=   5.6s
# [06:58:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.013 total time=   2.3s
# [06:58:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.014 total time=   2.3s
# [06:58:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.019 total time=   2.2s
# [06:58:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.015 total time=   2.3s
# [06:58:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.015 total time=   2.3s
# [06:58:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.013 total time=   5.5s
# [06:58:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.014 total time=   5.4s
# [06:58:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.019 total time=   5.4s
# [06:58:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.015 total time=   5.5s
# [06:58:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.015 total time=   5.4s
# [06:58:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.014 total time=   2.2s
# [06:58:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.016 total time=   2.2s
# [06:58:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.020 total time=   2.2s
# [06:58:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.014 total time=   2.2s
# [06:58:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.015 total time=   2.2s
# [06:58:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.014 total time=   5.4s
# [06:59:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.016 total time=   5.4s
# [06:59:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.020 total time=   7.1s
# [06:59:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.014 total time=   5.5s
# [06:59:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.015 total time=   5.5s
# [06:59:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=5, estimator=XGBRegressor(),
#              param_grid={'learning_rate': [0.01, 0.03, 0.05, 0.07, 0.09, 0.11,
#                                            0.13, 0.15, 0.17, 0.19],
#                          'max_depth': [3, 5, 7, 9],
#                          'n_estimators': [2000, 6000]},
#              scoring='neg_mean_squared_error', verbose=5)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'importance_type': 'gain',
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 6000,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:linear',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
# Training model with hyperparameter 

model = XGBRegressor(n_estimators = 6000, learning_rate = 0.01, gamma = 0, max_depth = 3  )
model.fit(x_train, y_train)
y_pre = model.predict(x_test)
print('Root mean squared' ,(mean_squared_error(y_pre,y_test )**(1/2)))
print('R2-scored ', r2_score(y_pre, y_test))
# Out:
# [09:14:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Root mean squared 0.07805544277635618
# R2-scored  0.9962017279178491
