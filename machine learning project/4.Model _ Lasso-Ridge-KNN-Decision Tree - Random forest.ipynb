# %% [markdown]
# # **I.Import library and load data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/machine learning project/processed data.csv")
data = data.drop(columns = ['Unnamed: 0'])
data.head()
# Out:
#    MP   Min  Goals  Assists  CrdY  CrdR        Comp  Shots  Acceleration  \
# 0  34  2983   0.06     0.00  0.15  0.03     Ligue 1   0.54            37
# 1  31  2462   0.04     0.00  0.44  0.11     Ligue 1   0.66            50
# 2  34  2956   0.00     0.06  0.27  0.00     Ligue 1   0.91            77
# 3  24   726   0.00     0.12  0.37  0.00  Bundesliga   2.22            81
# 4  30  2536   0.14     0.00  0.07  0.04     Serie A   0.57            64
#
#    Aggression  ...  Vision  Volleys  age               name  overall  \
# 0          81  ...      45       24   33   Yunis Abdelhamid       76
# 1          79  ...      65       38   21  Salis Abdul Samed       70
# 2          76  ...      66       37   28    Laurent Abergel       75
# 3          39  ...      44       53   22     Dickson Abiama       68
# 4          77  ...      65       39   33   Francesco Acerbi       83
#
#    potential  preferred_foot  position common  market value  wage value
# 0         76            Left         defender     3600000.0     23000.0
# 1         75           Right       midfielder     2200000.0      7000.0
# 2         75           Right       midfielder     4900000.0     18000.0
# 3         76           Right          striker     2700000.0      9000.0
# 4         83            Left         defender    17500000.0     75000.0
#
# [5 rows x 52 columns]

# %% [markdown]
# # **II. Convert category data into numeric data and remove columns that don't related in build model**

# %%
# Comp = name of league
data['Comp'].replace(data['Comp'].unique(),[1, 3, 2, 4, 5], inplace=True)
# drop name column and preferred_foot
data = data.drop(columns = ['name','preferred_foot'])

# %%
#convert the categorical variables to dummies
data = pd.get_dummies(data) 
# log tranformation for market vakue
data['market value'] = np.log(data['market value'])
data.head()
# Out:
#    MP   Min  Goals  Assists  CrdY  CrdR  Comp  Shots  Acceleration  \
# 0  34  2983   0.06     0.00  0.15  0.03     1   0.54            37
# 1  31  2462   0.04     0.00  0.44  0.11     1   0.66            50
# 2  34  2956   0.00     0.06  0.27  0.00     1   0.91            77
# 3  24   726   0.00     0.12  0.37  0.00     3   2.22            81
# 4  30  2536   0.14     0.00  0.07  0.04     2   0.57            64
#
#    Aggression  ...  Volleys  age  overall  potential  market value  \
# 0          81  ...       24   33       76         76     15.096444
# 1          79  ...       38   21       70         75     14.603968
# 2          76  ...       37   28       75         75     15.404746
# 3          39  ...       53   22       68         76     14.808762
# 4          77  ...       39   33       83         83     16.677711
#
#    wage value  position common_defender  position common_goalkeeper  \
# 0     23000.0                         1                           0
# 1      7000.0                         0                           0
# 2     18000.0                         0                           0
# 3      9000.0                         0                           0
# 4     75000.0                         1                           0
#
#    position common_midfielder  position common_striker
# 0                           0                        0
# 1                           1                        0
# 2                           1                        0
# 3                           0                        1
# 4                           0                        0
#
# [5 rows x 53 columns]

# %% [markdown]
# # **III.Correlation bettween independent varibales and target variables**

# %%
data.corr()['market value'].sort_values(ascending=False).iloc[1:].plot(kind='barh',figsize=(8,10))
plt.xlabel("Correlation with target variable")
plt.show()

# %% [markdown]
# # **IV.Model**

# %% [markdown]
# ## 1.Lasso - Ridge - KNN

# %% [markdown]
# ### 1.1.Feature scaling

# %%
data_build = data.copy()
y = data_build['market value']
x = data_build.drop(columns =['market value'])

# %%
# Standardization
def standard_scale(x):
    convert = StandardScaler().fit(x)
    return convert.transform(x)
x = standard_scale(x)

# %% [markdown]
# ### 1.2. Split training and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y , test_size = 0.33, random_state = 3 )

# %% [markdown]
# ### 1.3. Hyperparameter turing

# %% [markdown]
# #### 1.3.1.Lasso

# %%
regressor = Lasso()
params = {'alpha':[0.00001,0.00005,0.0001,0.0002,0.0003,0.0005,0.0007,0.0009,0.001,0.002,0.003,0.005,0.007,0.009
                   ,0.01,0.02,0.03,0.05,0.07,0.08,0.09,0.1,0.2,0.4,0.5,0.7,0.9,1,
                   1.1,1.2,1.3,1.5,1.7,1.9,2,2.5,3,4,5,7,10,20,30,50,100,200,300,500,1000,2000,5000,6000,7000,10000],
          'max_iter': [10000]}
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring= scoring_fnc, cv= 5 , verbose= 1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-05, 5e-05, 0.0001, 0.0002, 0.0003, 0.0005,
#                                    0.0007, 0.0009, 0.001, 0.002, 0.003, 0.005,
#                                    0.007, 0.009, 0.01, 0.02, 0.03, 0.05, 0.07,
#                                    0.08, 0.09, 0.1, 0.2, 0.4, 0.5, 0.7, 0.9, 1,
#                                    1.1, 1.2, ...],
#                          'max_iter': [10000]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'alpha': 0.005,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 10000,
#  'normalize': 'deprecated',
#  'positive': False,
#  'precompute': False,
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'warm_start': False}

# %%
#  Training model with hyperparameter tuning
model = Lasso(alpha = 0.005 , max_iter = 10000)
model.fit(x_train, y_train)
y_pre = model.predict(x_test)
print('Root mean squared' ,(mean_squared_error(y_pre,y_test )**(1/2)))
print('R2-scored ', r2_score(y_pre, y_test))
# Out:
# Root mean squared 0.221936440341696
# R2-scored  0.967581063962568

# %% [markdown]
# #### 1.3.2.Ridge

# %%
regressor = Ridge()
params = {'alpha':[0.00001,0.00005,0.0001,0.0002,0.0003,0.0005,0.0007,0.0009,0.001,0.002,0.003,0.005,0.007,0.009
                   ,0.01,0.02,0.03,0.05,0.07,0.08,0.09,0.1,0.2,0.4,0.5,0.7,0.9,1,
                   1.1,1.2,1.3,1.5,1.7,1.9,2,2.5,3,4,5,7,10,20,30,50,100,200,300,500,1000,2000,5000,6000,7000,10000],
         'fit_intercept' : [True, False]}
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring= scoring_fnc, cv=5 , verbose= 1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-05, 5e-05, 0.0001, 0.0002, 0.0003, 0.0005,
#                                    0.0007, 0.0009, 0.001, 0.002, 0.003, 0.005,
#                                    0.007, 0.009, 0.01, 0.02, 0.03, 0.05, 0.07,
#                                    0.08, 0.09, 0.1, 0.2, 0.4, 0.5, 0.7, 0.9, 1,
#                                    1.1, 1.2, ...],
#                          'fit_intercept': [True, False]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'alpha': 0.4,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'normalize': 'deprecated',
#  'positive': False,
#  'random_state': None,
#  'solver': 'auto',
#  'tol': 0.001}

# %%
# Training model with hyperparameter turning
model = Ridge(alpha = 0.4, fit_intercept = True)
model.fit(x_train, y_train)
# predict
y_pre = model.predict(x_test)
print('Root mean squared' ,(mean_squared_error(y_pre,y_test )**(1/2)))
print('R2-scored ', r2_score(y_pre, y_test))
# Out:
# Root mean squared 0.22603063142189242
# R2-scored  0.9669988183986586

# %% [markdown]
# #### 1.3.3. KNN

# %%
regressor =  KNeighborsRegressor()
params = {'n_neighbors':range(1,15) , 'weights' : ['uniform', 'distance'], 
          'metric' : ['euclidean','manhattan','minkowski','chebyshev']}
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring= scoring_fnc, cv=5 , verbose= 1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 112 candidates, totalling 560 fits
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski',
#                                     'chebyshev'],
#                          'n_neighbors': range(1, 15),
#                          'weights': ['uniform', 'distance']},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'manhattan',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 7,
#  'p': 2,
#  'weights': 'distance'}

# %%
# Training model with hyperparameter turning
model = KNeighborsRegressor(n_neighbors = 7,weights = 'distance', metric = 'manhattan')
#predict
model.fit(x_train, y_train)

y_pre = model.predict(x_test) 

print('Root mean squared' ,(mean_squared_error(y_pre,y_test )**(1/2)))
print('R2-scored ', r2_score(y_pre, y_test))
# Out:
# Root mean squared 0.38971366862658924
# R2-scored  0.867663755288164

# %% [markdown]
# ## 2 . Decision tree and Random forest

# %% [markdown]
# ### 2.1. Split training and test

# %%
data_tree = data.copy()
y = data_tree['market value']
x = data_tree.drop(columns =['market value'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y , test_size = 0.33, random_state = 3 )

# %% [markdown]
# ### 2.2.Hyperparameter Tunning

# %% [markdown]
# #### 2.2.1. Decision tree

# %%
regressor = DecisionTreeRegressor(random_state = 3)
params = {'max_depth':range(4,20),
         'criterion' :['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
         'max_features': [None, 0.5,'auto', 'sqrt','log2'],
          'min_samples_leaf':[1, 2,4] }
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring=scoring_fnc, cv=5, verbose= 5 )
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 960 candidates, totalling 4800 fits
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1;, score=-0.111 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1;, score=-0.143 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1;, score=-0.145 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1;, score=-0.150 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1;, score=-0.125 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=2;, score=-0.111 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=2;, score=-0.143 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=2;, score=-0.145 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=2;, score=-0.150 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=2;, score=-0.125 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=4;, score=-0.111 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=4;, score=-0.143 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=4;, score=-0.145 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=4;, score=-0.150 total time=   0.1s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=4;, score=-0.125 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=1;, score=-0.181 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=1;, score=-0.193 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=1;, score=-0.208 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=1;, score=-0.174 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=1;, score=-0.198 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=2;, score=-0.181 total time=   0.1s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=2;, score=-0.193 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=2;, score=-0.208 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=2;, score=-0.174 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=2;, score=-0.198 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=4;, score=-0.181 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=4;, score=-0.193 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=4;, score=-0.208 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=4;, score=-0.174 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=0.5, min_samples_leaf=4;, score=-0.198 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1;, score=-0.111 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1;, score=-0.143 total time=   0.1s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1;, score=-0.145 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1;, score=-0.150 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1;, score=-0.125 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=2;, score=-0.111 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=2;, score=-0.143 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=2;, score=-0.145 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=2;, score=-0.150 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=2;, score=-0.125 total time=   0.1s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=4;, score=-0.111 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=4;, score=-0.143 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=4;, score=-0.145 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=4;, score=-0.150 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=4;, score=-0.125 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=1;, score=-0.569 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=1;, score=-0.540 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=1;, score=-0.548 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=1;, score=-0.476 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=1;, score=-0.531 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=2;, score=-0.569 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=2;, score=-0.540 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=2;, score=-0.548 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=2;, score=-0.476 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=2;, score=-0.531 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=4;, score=-0.569 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=4;, score=-0.540 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=4;, score=-0.549 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=4;, score=-0.476 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=sqrt, min_samples_leaf=4;, score=-0.531 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1;, score=-0.746 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1;, score=-0.630 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1;, score=-0.757 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1;, score=-0.728 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1;, score=-0.694 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=2;, score=-0.746 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=2;, score=-0.636 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=2;, score=-0.757 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=2;, score=-0.718 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=2;, score=-0.694 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=4;, score=-0.745 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=4;, score=-0.636 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=4;, score=-0.799 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=4;, score=-0.663 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=4;, score=-0.694 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=1;, score=-0.070 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=1;, score=-0.097 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=1;, score=-0.090 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=1;, score=-0.077 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=1;, score=-0.081 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=2;, score=-0.070 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=2;, score=-0.083 total time=   0.1s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=2;, score=-0.090 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=2;, score=-0.077 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=2;, score=-0.081 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=4;, score=-0.069 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=4;, score=-0.086 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=4;, score=-0.089 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=4;, score=-0.078 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=None, min_samples_leaf=4;, score=-0.094 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=1;, score=-0.141 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=1;, score=-0.141 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=1;, score=-0.168 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=1;, score=-0.140 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=1;, score=-0.123 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=2;, score=-0.141 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=2;, score=-0.141 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=2;, score=-0.163 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=2;, score=-0.147 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=2;, score=-0.122 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=4;, score=-0.132 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=4;, score=-0.147 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=4;, score=-0.138 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=4;, score=-0.149 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=5, max_features=0.5, min_samples_leaf=4;, score=-0.117 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=5, max_features=auto, min_samples_leaf=1;, score=-0.070 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=5, max_features=auto, min_samples_leaf=1;, score=-0.097 total time=   0.1s
# [CV 3/5] END criterion=squared_error, max_depth=5, max_features=auto, min_samples_leaf
total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=1;, score=-1.338 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=2;, score=-1.105 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=2;, score=-1.172 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=2;, score=-1.077 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=2;, score=-1.210 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=2;, score=-1.137 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=4;, score=-0.903 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=4;, score=-0.950 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=4;, score=-0.982 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=4;, score=-0.963 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=0.5, min_samples_leaf=4;, score=-0.990 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=1;, score=-1.202 total time=   0.1s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=1;, score=-1.308 total time=   0.1s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=1;, score=-1.256 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=1;, score=-1.330 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=1;, score=-1.337 total time=   0.1s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=2;, score=-1.104 total time=   0.1s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=2;, score=-1.137 total time=   0.1s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=2;, score=-1.153 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=2;, score=-1.177 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=2;, score=-1.064 total time=   0.1s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=4;, score=-0.916 total time=   0.1s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=4;, score=-0.941 total time=   0.1s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=4;, score=-0.982 total time=   0.1s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=4;, score=-1.143 total time=   0.1s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=auto, min_samples_leaf=4;, score=-0.971 total time=   0.1s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=1;, score=-1.220 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=1;, score=-1.294 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=1;, score=-1.263 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=1;, score=-1.214 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=1;, score=-1.322 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=2;, score=-1.075 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=2;, score=-1.243 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=2;, score=-1.219 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=2;, score=-1.125 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=2;, score=-1.266 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=4;, score=-0.983 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=4;, score=-1.062 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=4;, score=-0.989 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=4;, score=-1.082 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=sqrt, min_samples_leaf=4;, score=-0.937 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=1;, score=-1.209 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=1;, score=-1.283 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=1;, score=-1.367 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=1;, score=-1.113 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=1;, score=-1.291 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=2;, score=-0.961 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=2;, score=-1.194 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=2;, score=-1.126 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=2;, score=-1.100 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=2;, score=-1.062 total time=   0.0s
# [CV 1/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=4;, score=-0.973 total time=   0.0s
# [CV 2/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=4;, score=-0.948 total time=   0.0s
# [CV 3/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=4;, score=-1.090 total time=   0.0s
# [CV 4/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=4;, score=-1.015 total time=   0.0s
# [CV 5/5] END criterion=poisson, max_depth=19, max_features=log2, min_samples_leaf=4;, score=-0.988 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=3),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': range(4, 20),
#                          'max_features': [None, 0.5, 'auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4]},
#              scoring='neg_mean_squared_error', verbose=5)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'max_depth': 16,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 3,
#  'splitter': 'best'}

# %%
# Training model with hyperparameter turning
model = DecisionTreeRegressor(random_state = 3,
                              criterion = 'friedman_mse', 
                              max_depth = 16 ,
                              max_features = None,
                              min_samples_leaf = 2 )
#predict
model.fit(x_train, y_train)

y_pre = model.predict(x_test) 

print('r2 score :', r2_score(y_pre, y_test))
print('Root mean squared  :' ,(mean_squared_error(y_pre,y_test )**(1/2)))
# Out:
# r2 score : 0.975740722816691
# Root mean squared  : 0.19550146475369884

# %% [markdown]
# #### 2.2.2. Random forest

# %%
regressor = RandomForestRegressor(random_state = 3)
params = {'n_estimators':[300,500],
         'max_features': [None, 0.5,'auto', 'sqrt'],
          'min_samples_leaf':[1,4]
         }
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring=scoring_fnc, cv=5, verbose= 1 )
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=3),
#              param_grid={'max_features': [None, 0.5, 'auto', 'sqrt'],
#                          'min_samples_leaf': [1, 4],
#                          'n_estimators': [300, 500]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 500,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 3,
#  'verbose': 0,
#  'warm_start': False}

# %%
# Training model with hyperparameter turning
model = RandomForestRegressor(random_state = 3, n_estimators = 500,
                              max_features = None, min_samples_leaf = 1
                             )
model.fit(x_train, y_train)
#predict
y_pre = model.predict(x_test) 

print('r2 score :', r2_score(y_pre, y_test))
print('Root mean squared error: ' ,(mean_squared_error(y_pre,y_test )**(1/2)))
# Out:
# r2 score : 0.9920981681987293
# Root mean squared error:  0.11025607993364234
