# %% [markdown]
# # **I. Import library and load data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import lightgbm as lgb

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/machine learning project/processed data.csv")
data = data.drop(columns = ['Unnamed: 0'])
data.head()
# Out:
#    MP   Min  Goals  Assists  CrdY  CrdR        Comp  Shots  Acceleration  \
# 0  34  2983   0.06     0.00  0.15  0.03     Ligue 1   0.54            37
# 1  31  2462   0.04     0.00  0.44  0.11     Ligue 1   0.66            50
# 2  34  2956   0.00     0.06  0.27  0.00     Ligue 1   0.91            77
# 3  24   726   0.00     0.12  0.37  0.00  Bundesliga   2.22            81
# 4  30  2536   0.14     0.00  0.07  0.04     Serie A   0.57            64
#
#    Aggression  ...  Vision  Volleys  age               name  overall  \
# 0          81  ...      45       24   33   Yunis Abdelhamid       76
# 1          79  ...      65       38   21  Salis Abdul Samed       70
# 2          76  ...      66       37   28    Laurent Abergel       75
# 3          39  ...      44       53   22     Dickson Abiama       68
# 4          77  ...      65       39   33   Francesco Acerbi       83
#
#    potential  preferred_foot  position common  market value  wage value
# 0         76            Left         defender     3600000.0     23000.0
# 1         75           Right       midfielder     2200000.0      7000.0
# 2         75           Right       midfielder     4900000.0     18000.0
# 3         76           Right          striker     2700000.0      9000.0
# 4         83            Left         defender    17500000.0     75000.0
#
# [5 rows x 52 columns]

# %% [markdown]
# # **II. Convert category data into numeric data and remove columns that don't related in build model**

# %%
# Comp = name of league
data['Comp'].replace(data['Comp'].unique(),[1, 3, 2, 4, 5], inplace=True)
# drop name column and preferred_foot
data = data.drop(columns = ['name','preferred_foot'])

# %%
#convert the categorical variables to dummies
data = pd.get_dummies(data) 
# log tranformation for market vakue
data['market value'] = np.log(data['market value'])
data.head()
# Out:
#    MP   Min  Goals  Assists  CrdY  CrdR  Comp  Shots  Acceleration  \
# 0  34  2983   0.06     0.00  0.15  0.03     1   0.54            37
# 1  31  2462   0.04     0.00  0.44  0.11     1   0.66            50
# 2  34  2956   0.00     0.06  0.27  0.00     1   0.91            77
# 3  24   726   0.00     0.12  0.37  0.00     3   2.22            81
# 4  30  2536   0.14     0.00  0.07  0.04     2   0.57            64
#
#    Aggression  ...  Volleys  age  overall  potential  market value  \
# 0          81  ...       24   33       76         76     15.096444
# 1          79  ...       38   21       70         75     14.603968
# 2          76  ...       37   28       75         75     15.404746
# 3          39  ...       53   22       68         76     14.808762
# 4          77  ...       39   33       83         83     16.677711
#
#    wage value  position common_defender  position common_goalkeeper  \
# 0     23000.0                         1                           0
# 1      7000.0                         0                           0
# 2     18000.0                         0                           0
# 3      9000.0                         0                           0
# 4     75000.0                         1                           0
#
#    position common_midfielder  position common_striker
# 0                           0                        0
# 1                           1                        0
# 2                           1                        0
# 3                           0                        1
# 4                           0                        0
#
# [5 rows x 53 columns]

# %% [markdown]
# # **III. Split training and test**

# %%
data_build = data.copy()
y = data_build['market value']
x = data_build.drop(columns =['market value'])

x_train, x_test, y_train, y_test = train_test_split(x,y , test_size = 0.33, random_state = 3 )

# %% [markdown]
# # **IV.Emsemble models : LightGBM**

# %% [markdown]
# ## 1.Hyperparameter turing

# %%
regressor = lgb.LGBMRegressor()
params = {
    'n_estimators': [100,200,1000, 2000],
    'learning_rate': [x/100 for x in range(1, 21, 2)],
    'reg_alpha': [0, 1e-1, 1, 2, 5, 7, 10, 50, 100],
    'reg_lambda': [0, 1e-1, 1, 5, 10, 20, 50, 100],
    'max_depth':[int(x) for x in range(3, 11, 2)]
}
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring= scoring_fnc, cv= 5 , verbose= 5)
grid.fit(x_train, y_train)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=1000, reg_alpha=0.1, reg_lambda=

# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=1;, score=-0.016 total time=   1.0s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=1;, score=-0.014 total time=   0.9s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=5;, score=-0.013 total time=   0.9s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=5;, score=-0.011 total time=   1.0s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=5;, score=-0.012 total time=   0.9s
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=5;, score=-0.017 total time=   1.0s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=5;, score=-0.017 total time=   0.9s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=10;, score=-0.013 total time=   1.0s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=10;, score=-0.013 total time=   1.0s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=10;, score=-0.013 total time=   0.9s
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=10;, score=-0.014 total time=   1.0s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=10;, score=-0.015 total time=   1.0s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=20;, score=-0.014 total time=   1.0s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=20;, score=-0.013 total time=   1.0s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=20;, score=-0.014 total time=   1.0s
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=20;, score=-0.017 total time=   0.9s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=20;, score=-0.016 total time=   1.0s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=50;, score=-0.015 total time=   1.0s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=50;, score=-0.014 total time=   1.0s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=50;, score=-0.016 total time=   1.0s
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=50;, score=-0.018 total time=   1.0s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=50;, score=-0.017 total time=   1.0s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=100;, score=-0.018 total time=   1.0s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=100;, score=-0.015 total time=   1.0s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=100;, score=-0.016 total time=   1.0s
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=100;, score=-0.018 total time=   1.0s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0, reg_lambda=100;, score=-0.017 total time=   1.0s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0;, score=-0.015 total time=   0.5s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0;, score=-0.011 total time=   0.5s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0;, score=-0.012 total time=   0.5s
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0;, score=-0.018 total time=   0.5s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0;, score=-0.015 total time=   0.5s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0.1;, score=-0.015 total time=   0.5s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0.1;, score=-0.013 total time=   0.6s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0.1;, score=-0.012 total time=   0.5s
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0.1;, score=-0.016 total time=   0.5s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=0.1;, score=-0.014 total time=   0.5s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=1;, score=-0.014 total time=   0.5s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=1;, score=-0.014 total time=   0.5s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=1;, score=-0.013 total time=   0.5s
# [CV 4/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=1;, score=-0.018 total time=   0.5s
# [CV 5/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=1;, score=-0.014 total time=   0.5s
# [CV 1/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=5;, score=-0.012 total time=   0.5s
# [CV 2/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=5;, score=-0.011 total time=   0.6s
# [CV 3/5] END learning_rate=0.19, max_depth=3, n_estimators=2000, reg_alpha=0.1, reg_lambda=5;, score=-0.013 total time=   0.5s
# ...
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=7, reg_lambda=100;, score=-0.037 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0;, score=-0.040 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0;, score=-0.031 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0;, score=-0.050 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0;, score=-0.031 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0;, score=-0.039 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0.1;, score=-0.040 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0.1;, score=-0.031 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0.1;, score=-0.050 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0.1;, score=-0.031 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=0.1;, score=-0.039 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=1;, score=-0.039 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=1;, score=-0.030 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=1;, score=-0.051 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=1;, score=-0.034 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=1;, score=-0.042 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=5;, score=-0.041 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=5;, score=-0.031 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=5;, score=-0.050 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=5;, score=-0.033 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=5;, score=-0.039 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=10;, score=-0.042 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=10;, score=-0.029 total time=   0.4s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=10;, score=-0.053 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=10;, score=-0.033 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=10;, score=-0.039 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=20;, score=-0.040 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=20;, score=-0.032 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=20;, score=-0.052 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=20;, score=-0.035 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=20;, score=-0.044 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=50;, score=-0.043 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=50;, score=-0.034 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=50;, score=-0.052 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=50;, score=-0.036 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=50;, score=-0.044 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=100;, score=-0.046 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=100;, score=-0.039 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=100;, score=-0.054 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=100;, score=-0.037 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=10, reg_lambda=100;, score=-0.046 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0;, score=-0.144 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0;, score=-0.162 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0;, score=-0.187 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0;, score=-0.135 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0;, score=-0.158 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0.1;, score=-0.143 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0.1;, score=-0.162 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0.1;, score=-0.187 total time=   0.4s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0.1;, score=-0.135 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=0.1;, score=-0.158 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=1;, score=-0.144 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=1;, score=-0.162 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=1;, score=-0.184 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=1;, score=-0.135 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=1;, score=-0.158 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=5;, score=-0.142 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=5;, score=-0.163 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=5;, score=-0.184 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=5;, score=-0.133 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=5;, score=-0.158 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=10;, score=-0.145 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=10;, score=-0.162 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=10;, score=-0.182 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=10;, score=-0.136 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=10;, score=-0.157 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=20;, score=-0.141 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=20;, score=-0.164 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=20;, score=-0.180 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=20;, score=-0.135 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=20;, score=-0.162 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=50;, score=-0.140 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=50;, score=-0.163 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=50;, score=-0.182 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=50;, score=-0.134 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=50;, score=-0.162 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=100;, score=-0.139 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=100;, score=-0.165 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=100;, score=-0.179 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=100;, score=-0.135 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=50, reg_lambda=100;, score=-0.160 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0;, score=-0.233 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0;, score=-0.288 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0;, score=-0.308 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0;, score=-0.239 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0;, score=-0.271 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0.1;, score=-0.233 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0.1;, score=-0.288 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0.1;, score=-0.308 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0.1;, score=-0.239 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=0.1;, score=-0.271 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=1;, score=-0.235 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=1;, score=-0.293 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=1;, score=-0.307 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=1;, score=-0.239 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=1;, score=-0.271 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=5;, score=-0.235 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=5;, score=-0.291 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=5;, score=-0.306 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=5;, score=-0.241 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=5;, score=-0.273 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=10;, score=-0.237 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=10;, score=-0.287 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=10;, score=-0.307 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=10;, score=-0.242 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=10;, score=-0.273 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=20;, score=-0.238 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=20;, score=-0.292 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=20;, score=-0.303 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=20;, score=-0.242 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=20;, score=-0.270 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=50;, score=-0.238 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=50;, score=-0.290 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=50;, score=-0.310 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=50;, score=-0.243 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=50;, score=-0.270 total time=   0.3s
# [CV 1/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=100;, score=-0.239 total time=   0.3s
# [CV 2/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=100;, score=-0.300 total time=   0.3s
# [CV 3/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=100;, score=-0.308 total time=   0.3s
# [CV 4/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=100;, score=-0.238 total time=   0.3s
# [CV 5/5] END learning_rate=0.19, max_depth=9, n_estimators=2000, reg_alpha=100, reg_lambda=100;, score=-0.272 total time=   0.3s
# GridSearchCV(cv=5, estimator=LGBMRegressor(),
#              param_grid={'learning_rate': [0.01, 0.03, 0.05, 0.07, 0.09, 0.11,
#                                            0.13, 0.15, 0.17, 0.19],
#                          'max_depth': [3, 5, 7, 9],
#                          'n_estimators': [100, 200, 1000, 2000],
#                          'reg_alpha': [0, 0.1, 1, 2, 5, 7, 10, 50, 100],
#                          'reg_lambda': [0, 0.1, 1, 5, 10, 20, 50, 100]},
#              scoring='neg_mean_squared_error', verbose=5)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.05,
#  'max_depth': 3,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 1000,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.1,
#  'reg_lambda': 1,
#  'silent': True,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %% [markdown]
# # 2. Training model with hyperparameter

# %%
# Training model with hyperparameter 
model = lgb.LGBMRegressor(n_estimators = 1000, learning_rate = 0.05, reg_alpha = 0.1,
                          reg_lambda  = 1, max_depth = 3)
model.fit(x_train, y_train)
#predict
y_pre = model.predict(x_test) 
print('Root mean squared' ,(mean_squared_error(y_pre,y_test )**(1/2)))
print('R2-scored ', r2_score(y_pre, y_test))
# Out:
# Root mean squared 0.09735391781435403
# R2-scored  0.9939875216024947
