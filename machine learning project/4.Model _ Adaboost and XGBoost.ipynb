# %% [markdown]
# # I. Import library and load data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/machine learning project/processed data.csv")
data = data.drop(columns = ['Unnamed: 0'])
data.head()
# Out:
#    MP   Min  Goals  Assists  CrdY  CrdR        Comp  Shots  Acceleration  \
# 0  34  2983   0.06     0.00  0.15  0.03     Ligue 1   0.54            37
# 1  31  2462   0.04     0.00  0.44  0.11     Ligue 1   0.66            50
# 2  34  2956   0.00     0.06  0.27  0.00     Ligue 1   0.91            77
# 3  24   726   0.00     0.12  0.37  0.00  Bundesliga   2.22            81
# 4  30  2536   0.14     0.00  0.07  0.04     Serie A   0.57            64
#
#    Aggression  ...  Vision  Volleys  age               name  overall  \
# 0          81  ...      45       24   33   Yunis Abdelhamid       76
# 1          79  ...      65       38   21  Salis Abdul Samed       70
# 2          76  ...      66       37   28    Laurent Abergel       75
# 3          39  ...      44       53   22     Dickson Abiama       68
# 4          77  ...      65       39   33   Francesco Acerbi       83
#
#    potential  preferred_foot  position common  market value  wage value
# 0         76            Left         defender     3600000.0     23000.0
# 1         75           Right       midfielder     2200000.0      7000.0
# 2         75           Right       midfielder     4900000.0     18000.0
# 3         76           Right          striker     2700000.0      9000.0
# 4         83            Left         defender    17500000.0     75000.0
#
# [5 rows x 52 columns]

# %% [markdown]
# # II. Convert category data into numeric data and remove columns that don't related in build model

# %%
# Comp = name of league
data['Comp'].replace(data['Comp'].unique(),[1, 3, 2, 4, 5], inplace=True)
# drop name column and preferred_foot
data = data.drop(columns = ['name','preferred_foot'])

# %%
#convert the categorical variables to dummies
data = pd.get_dummies(data) 
# log tranformation for market vakue
data['market value'] = np.log(data['market value'])
data.head()
# Out:
#    MP   Min  Goals  Assists  CrdY  CrdR  Comp  Shots  Acceleration  \
# 0  34  2983   0.06     0.00  0.15  0.03     1   0.54            37
# 1  31  2462   0.04     0.00  0.44  0.11     1   0.66            50
# 2  34  2956   0.00     0.06  0.27  0.00     1   0.91            77
# 3  24   726   0.00     0.12  0.37  0.00     3   2.22            81
# 4  30  2536   0.14     0.00  0.07  0.04     2   0.57            64
#
#    Aggression  ...  Volleys  age  overall  potential  market value  \
# 0          81  ...       24   33       76         76     15.096444
# 1          79  ...       38   21       70         75     14.603968
# 2          76  ...       37   28       75         75     15.404746
# 3          39  ...       53   22       68         76     14.808762
# 4          77  ...       39   33       83         83     16.677711
#
#    wage value  position common_defender  position common_goalkeeper  \
# 0     23000.0                         1                           0
# 1      7000.0                         0                           0
# 2     18000.0                         0                           0
# 3      9000.0                         0                           0
# 4     75000.0                         1                           0
#
#    position common_midfielder  position common_striker
# 0                           0                        0
# 1                           1                        0
# 2                           1                        0
# 3                           0                        1
# 4                           0                        0
#
# [5 rows x 53 columns]

# %% [markdown]
# # III. Split training and test

# %%
data_build = data.copy()
y = data_build['market value']
x = data_build.drop(columns =['market value'])
x_train, x_test, y_train, y_test = train_test_split(x,y , test_size = 0.33, random_state = 3 )

# %% [markdown]
# # IV.Emsemble models

# %% [markdown]
# ## 1. Adaboost

# %%
DCT = DecisionTreeRegressor(random_state=0, max_depth = 13)
regressor = AdaBoostRegressor(base_estimator = DCT)
params = {'n_estimators': range(1,100,3),'random_state' : [3],
         }
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring= scoring_fnc, cv= 5 , verbose= 1)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 33 candidates, totalling 165 fits
# GridSearchCV(cv=5,
#              estimator=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=13,
#                                                                               random_state=0)),
#              param_grid={'n_estimators': range(1, 100, 3), 'random_state': [3]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'base_estimator': DecisionTreeRegressor(max_depth=13, random_state=0),
#  'base_estimator__ccp_alpha': 0.0,
#  'base_estimator__criterion': 'squared_error',
#  'base_estimator__max_depth': 13,
#  'base_estimator__max_features': None,
#  'base_estimator__max_leaf_nodes': None,
#  'base_estimator__min_impurity_decrease': 0.0,
#  'base_estimator__min_samples_leaf': 1,
#  'base_estimator__min_samples_split': 2,
#  'base_estimator__min_weight_fraction_leaf': 0.0,
#  'base_estimator__random_state': 0,
#  'base_estimator__splitter': 'best',
#  'learning_rate': 1.0,
#  'loss': 'linear',
#  'n_estimators': 94,
#  'random_state': 3}

# %%
#  Training model with hyperparameter tuning
model = AdaBoostRegressor(base_estimator = DecisionTreeRegressor(max_depth=13, random_state=0)
                          ,n_estimators = 94, learning_rate = 1.0, random_state = 3)
model.fit(x_train, y_train)
y_pre = model.predict(x_test)
print('Root mean squared' ,(mean_squared_error(y_pre,y_test )**(1/2)))
print('R2-scored ', r2_score(y_pre, y_test))
# Out:
# Root mean squared 0.12748218988490542
# R2-scored  0.9894280792870761

# %% [markdown]
# ##2. XGBoost

# %%
regressor = XGBRegressor()

params = {
    'n_estimators': [500,1000,2000,6000],
    
    'learning_rate': [x/100 for x in range(1, 21, 2)],
    'gamma': [x/5 for x in range(0, 3, 1)],
    'max_depth':[int(x) for x in range(3, 11, 2)]
}
scoring_fnc = 'neg_mean_squared_error'
grid = GridSearchCV(estimator=regressor, param_grid=params, scoring= scoring_fnc, cv= 5 , verbose= 5)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits
# [15:26:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=500;, score=-0.026 total time=   1.1s
# [15:26:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=500;, score=-0.025 total time=   1.0s
# [15:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=500;, score=-0.027 total time=   1.0s
# [15:26:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=500;, score=-0.022 total time=   1.0s
# [15:26:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=500;, score=-0.030 total time=   1.0s
# [15:26:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=1000;, score=-0.011 total time=   1.9s
# [15:26:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=1000;, score=-0.009 total time=   2.0s
# [15:26:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=1000;, score=-0.009 total time=   1.9s
# [15:26:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=1000;, score=-0.009 total time=   1.9s
# [15:27:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=1000;, score=-0.010 total time=   1.9s
# [15:27:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.010 total time=   3.9s
# [15:27:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.009 total time=   4.8s
# [15:27:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.008 total time=   3.8s
# [15:27:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.008 total time=   3.8s
# [15:27:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=2000;, score=-0.009 total time=   3.8s
# [15:27:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.009 total time=  11.7s
# [15:27:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.008 total time=  13.0s
# [15:27:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.008 total time=  11.6s
# [15:28:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.008 total time=  11.6s
# [15:28:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=3, n_estimators=6000;, score=-0.008 total time=  13.8s
# [15:28:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=500;, score=-0.024 total time=   1.5s
# [15:28:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=500;, score=-0.026 total time=   1.5s
# [15:28:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=500;, score=-0.026 total time=   1.5s
# [15:28:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=500;, score=-0.025 total time=   1.5s
# [15:28:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=500;, score=-0.026 total time=   1.5s
# [15:28:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=1000;, score=-0.010 total time=   3.1s
# [15:28:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=1000;, score=-0.012 total time=   3.1s
# [15:28:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=1000;, score=-0.011 total time=   3.1s
# [15:28:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=1000;, score=-0.012 total time=   3.0s
# [15:28:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=1000;, score=-0.012 total time=   3.1s
# [15:28:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.010 total time=   6.5s
# [15:28:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.012 total time=   6.6s
# [15:29:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.011 total time=   6.6s
# [15:29:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.011 total time=   6.5s
# [15:29:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=2000;, score=-0.011 total time=   8.0s
# [15:29:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.009 total time=  19.2s
# [15:29:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.012 total time=  18.9s
# [15:30:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.011 total time=  18.6s
# [15:30:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.011 total time=  18.6s
# [15:30:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=5, n_estimators=6000;, score=-0.011 total time=  20.7s
# [15:30:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=500;, score=-0.024 total time=   1.8s
# [15:31:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=500;, score=-0.026 total time=   1.8s
# [15:31:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=500;, score=-0.026 total time=   1.9s
# [15:31:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=500;, score=-0.025 total time=   1.8s
# [15:31:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=500;, score=-0.026 total time=   1.8s
# [15:31:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=1000;, score=-0.010 total time=   4.3s
# [15:31:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=1000;, score=-0.012 total time=   4.3s
# [15:31:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=1000;, score=-0.012 total time=   4.4s
# [15:31:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=1000;, score=-0.012 total time=   4.2s
# [15:31:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=1000;, score=-0.011 total time=   4.3s
# [15:31:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.009 total time=   9.7s
# [15:31:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.012 total time=   9.7s
# [15:31:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.011 total time=   9.6s
# [15:31:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.012 total time=   9.5s
# [15:32:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=2000;, score=-0.011 total time=   9.6s
# [15:32:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.009 total time=  17.7s
# [15:32:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.012 total time=  16.3s
# [15:32:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.011 total time=  16.1s
# [15:33:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.012 total time=  16.3s
# [15:33:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=7, n_estimators=6000;, score=-0.011 total time=  16.3s
# [15:33:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=9, n_estimators=500;, score=-0.024 total time=   2.0s
# [15:33:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=9, n_estimators=500;, score=-0.026 total time=   2.0s
# [15:33:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=9, n_estimators=500;, score=-0.027 total time=   2.0s
# [15:33:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.0, learning_rate=0.01, max_depth=9, n_estimators=500;, score=-0.025 total time=   2.0s
# [15:33:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.0, learning_rate=0.01, max_depth=9, n_estimators=500;, score=-0.026 total time=   2.0s
# [15:33:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.0, learning_rate=0.01, max_depth=9, n_estimators=1000;, score=-0.010 total time=   5.3s
# [15:33:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.0, learning_rate=0.01, max_depth=9, n_estimators=1000;, score=-0.013 total time=   5.6s
# [15:34:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.0, learning_rate=0.01, max_depth=9, n_estimators=1000;, score=
46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=500;, score=-0.023 total time=   2.3s
# [20:49:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=1000;, score=-0.017 total time=   3.9s
# [20:49:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=1000;, score=-0.014 total time=   3.6s
# [20:49:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=1000;, score=-0.025 total time=   3.4s
# [20:49:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=1000;, score=-0.019 total time=   3.2s
# [20:50:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=1000;, score=-0.023 total time=   3.0s
# [20:50:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.017 total time=   6.5s
# [20:50:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.014 total time=   7.1s
# [20:50:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.025 total time=   6.8s
# [20:50:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.019 total time=   6.4s
# [20:50:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=2000;, score=-0.023 total time=   6.0s
# [20:50:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.017 total time=  19.5s
# [20:50:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.014 total time=  22.8s
# [20:51:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.025 total time=  20.2s
# [20:51:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.019 total time=  19.1s
# [20:52:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=5, n_estimators=6000;, score=-0.023 total time=  19.3s
# [20:52:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=500;, score=-0.017 total time=   2.5s
# [20:52:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=500;, score=-0.014 total time=   2.6s
# [20:52:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=500;, score=-0.024 total time=   2.8s
# [20:52:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=500;, score=-0.019 total time=   2.6s
# [20:52:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=500;, score=-0.023 total time=   2.4s
# [20:52:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=1000;, score=-0.017 total time=   5.0s
# [20:52:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=1000;, score=-0.014 total time=   5.2s
# [20:52:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=1000;, score=-0.024 total time=   5.5s
# [20:52:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=1000;, score=-0.019 total time=   5.2s
# [20:52:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=1000;, score=-0.023 total time=   4.9s
# [20:52:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.017 total time=  10.0s
# [20:53:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.014 total time=  10.4s
# [20:53:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.024 total time=  12.4s
# [20:53:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.019 total time=  10.5s
# [20:53:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=2000;, score=-0.023 total time=   9.8s
# [20:53:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.017 total time=  29.9s
# [20:54:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.014 total time=  32.7s
# [20:54:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.024 total time=  33.2s
# [20:55:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.019 total time=  32.9s
# [20:56:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=7, n_estimators=6000;, score=-0.023 total time=  29.2s
# [20:56:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=500;, score=-0.017 total time=   3.5s
# [20:56:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=500;, score=-0.014 total time=   3.7s
# [20:56:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=500;, score=-0.024 total time=   4.0s
# [20:56:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=500;, score=-0.019 total time=   3.9s
# [20:56:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=500;, score=-0.023 total time=   3.6s
# [20:56:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=1000;, score=-0.017 total time=   7.0s
# [20:56:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=1000;, score=-0.014 total time=   7.5s
# [20:57:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=1000;, score=-0.024 total time=   9.5s
# [20:57:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=1000;, score=-0.019 total time=   7.8s
# [20:57:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=1000;, score=-0.023 total time=   7.3s
# [20:57:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.017 total time=  14.0s
# [20:57:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.014 total time=  15.1s
# [20:57:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.024 total time=  16.4s
# [20:58:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.019 total time=  17.0s
# [20:58:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=2000;, score=-0.023 total time=  14.7s
# [20:58:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 1/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.017 total time=  42.0s
# [20:59:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 2/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.014 total time=  46.7s
# [21:00:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 3/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.024 total time=  51.0s
# [21:01:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 4/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.019 total time=  47.0s
# [21:01:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV 5/5] END gamma=0.4, learning_rate=0.19, max_depth=9, n_estimators=6000;, score=-0.023 total time=  45.6s
# [21:02:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv=5, estimator=XGBRegressor(),
#              param_grid={'gamma': [0.0, 0.2, 0.4],
#                          'learning_rate': [0.01, 0.03, 0.05, 0.07, 0.09, 0.11,
#                                            0.13, 0.15, 0.17, 0.19],
#                          'max_depth': [3, 5, 7, 9],
#                          'n_estimators': [500, 1000, 2000, 6000]},
#              scoring='neg_mean_squared_error', verbose=5)

# %%
# get best parameter
grid.best_estimator_.get_params()
# Out:
# {'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0.0,
#  'importance_type': 'gain',
#  'learning_rate': 0.03,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 2000,
#  'n_jobs': 1,
#  'nthread': None,
#  'objective': 'reg:linear',
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': None,
#  'silent': None,
#  'subsample': 1,
#  'verbosity': 1}

# %%
#  Training model with hyperparameter tuning
model = XGBRegressor(n_estimators = 2000, learning_rate = 0.03, gamma = 0.0, max_depth = 3  )
model.fit(x_train, y_train)
y_pre = model.predict(x_test)
print('Root mean squared' ,(mean_squared_error(y_pre,y_test )**(1/2)))
print('R2-scored ', r2_score(y_pre, y_test))
# Out:
# [06:02:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Root mean squared 0.07013753747205126
# R2-scored  0.9968735027541525
